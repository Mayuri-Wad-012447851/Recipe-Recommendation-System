# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#read input file
r =pd.read_json("full_format_recipes.json")
recipe = r[['title','rating', 'calories', 'protein', 'fat', 'sodium', 'categories']]

# %%
recipe.head(5)
# Out:
#                                          title  rating  calories  protein  \
# 0              Lentil, Apple, and Turkey Wrap    2.500     426.0     30.0
# 1  Boudin Blanc Terrine with Red Onion Confit    4.375     403.0     18.0
# 2                Potato and Fennel Soup Hodge    3.750     165.0      6.0
# 3             Mahi-Mahi in Tomato Olive Sauce    5.000       NaN      NaN
# 4                    Spinach Noodle Casserole    3.125     547.0     20.0
#
#     fat  sodium                                         categories
# 0   7.0   559.0  [Sandwich, Bean, Fruit, Tomato, turkey, Vegeta...
# 1  23.0  1439.0  [Food Processor, Onion, Pork, Bake, Bastille D...
# 2   7.0   165.0  [Soup/Stew, Dairy, Potato, Vegetable, Fennel, ...
# 3   NaN     NaN  [Fish, Olive, Tomato, Sauté, Low Fat, Low Cal,...
# 4  32.0   452.0  [Cheese, Dairy, Pasta, Vegetable, Side, Bake, ...

# %%
recipe["calories"].fillna(0, inplace=True)
recipe["protein"].fillna(0, inplace=True)
recipe["fat"].fillna(0, inplace=True)
recipe["sodium"].fillna(0, inplace=True)
# Out:
# C:\Users\unnat\Anaconda3\lib\site-packages\pandas\core\generic.py:3660: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
recipe.head(10)
# Out:
#                                                title  rating  calories  \
# 0                    Lentil, Apple, and Turkey Wrap    2.500     426.0
# 1        Boudin Blanc Terrine with Red Onion Confit    4.375     403.0
# 2                      Potato and Fennel Soup Hodge    3.750     165.0
# 3                   Mahi-Mahi in Tomato Olive Sauce    5.000       0.0
# 4                          Spinach Noodle Casserole    3.125     547.0
# 5                                     The Best Blts    4.375     948.0
# 6  Ham and Spring Vegetable Salad with Shallot Vi...   4.375       0.0
# 7                              Spicy-Sweet Kumquats    3.750       0.0
# 8                             Korean Marinated Beef    4.375     170.0
# 9  Ham Persillade with Mustard Potato Salad and M...   3.750     602.0
#
#    protein   fat  sodium                                         categories
# 0     30.0   7.0   559.0  [Sandwich, Bean, Fruit, Tomato, turkey, Vegeta...
# 1     18.0  23.0  1439.0  [Food Processor, Onion, Pork, Bake, Bastille D...
# 2      6.0   7.0   165.0  [Soup/Stew, Dairy, Potato, Vegetable, Fennel, ...
# 3      0.0   0.0     0.0  [Fish, Olive, Tomato, Sauté, Low Fat, Low Cal,...
# 4     20.0  32.0   452.0  [Cheese, Dairy, Pasta, Vegetable, Side, Bake, ...
# 5     19.0  79.0  1042.0  [Sandwich, Food Processor, Tomato, Kid-Friendl...
# 6      0.0   0.0     0.0  [Salad, Potato, Side, Easter, Low Fat, Quick &...
# 7      0.0   0.0     0.0  [Egg, Fruit, No-Cook, Cocktail Party, Vegetari...
# 8      7.0  10.0  1272.0  [Beef, Ginger, Sauté, Stir-Fry, Quick & Easy, ...
# 9     23.0  41.0  1696.0  [Salad, Mustard, Potato, Picnic, Lunch, Mayonn...

# %%
#Plot Calories against Ratings
sns.set(font_scale=2)

fig, ax = plt.subplots(figsize=(10,10))


sns.barplot(x='rating',y='calories', data=recipe, errwidth =0)
ax.set_title('Rating vs Calories', size=30)
ax.set_ylabel('Calories')
ax.set_xlabel('Rating')

plt.show()

# %%
#Plot Protein against Ratings
sns.set(font_scale=2)

fig, ax = plt.subplots(figsize=(10,10))


sns.barplot(x='rating',y='protein', data=recipe, errwidth =0)
ax.set_title('Rating vs Protein', size=30)
ax.set_ylabel('Protein')
ax.set_xlabel('Rating')

plt.show()

# %%
#Plot Fat against Ratings
sns.set(font_scale=2)

fig, ax = plt.subplots(figsize=(10,10))


sns.barplot(x='rating',y='fat', data=recipe, errwidth =0)
ax.set_title('Rating vs Fat', size=30)
ax.set_ylabel('Fat')
ax.set_xlabel('Rating')

plt.show()

# %%
#Plot Sodium against Ratings
sns.set(font_scale=2)

fig, ax = plt.subplots(figsize=(10,10))


sns.barplot(x='rating',y='sodium', data=recipe, errwidth =0)
ax.set_title('Rating vs Sodium', size=30)
ax.set_ylabel('Sodium')
ax.set_xlabel('Rating')

plt.show()

# %%
#Plot recipes with the most ratings
recipe1 = recipe[['title','rating']]

top_recipes = recipe1.title.value_counts()[:10]
plt.figure(figsize=(12, 8))
pos = np.arange(len(top_recipes))
plt.barh(pos, top_recipes.values);
plt.yticks(pos, top_recipes.index);
plt.title('Recipes with the most ratings')
plt.xlabel('Rating Count')
plt.ylabel('Title')
# Out:
# Text(0,0.5,'Title')

# %%
top_recipes
# Out:
# Pastry Dough            28
# Chicken Stock           26
# Turkey Giblet Stock     20
# Simple Syrup            15
# Turkey Stock            15
# Pizza Dough             11
# Salsa Verde             11
# Tomatillo Salsa         10
# White Fish Stock         9
# Pickled Red Onions       9
# Name: title, dtype: int64

# %%
plt.show()

# %%
re =  recipe1['rating'].value_counts()
re
# Out:
# 4.375    8033
# 3.750    5174
# 5.000    2731
# 0.000    1849
# 3.125    1489
# 2.500     536
# 1.250     164
# 1.875     124
# Name: rating, dtype: int64

# %%
#Number of recipes per Rating
plt.figure(figsize=(12, 8))
pos = np.arange(len(re))
plt.barh(pos, re.values);
plt.yticks(pos, re.index);
plt.title('Number of Recipes per Rating')
plt.xlabel('Number of Recipes')
plt.ylabel('Rating')
# Out:
# Text(0,0.5,'Rating')

# %%
plt.show()
